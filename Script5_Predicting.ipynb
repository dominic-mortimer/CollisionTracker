# %%
import numpy as np
import pandas as pd

# %%
joined = pd.read_csv('Data/Montreal/Final/joined_by_hour.csv')
new = pd.read_csv('Data/Montreal/Final/joined_by_hour.csv')
collisions = pd.read_csv('Data/Montreal/Final/collisions_cleaned.csv')

joined.head()
# Out:
#    Id_Intersection        Date  hour  Longitude  Latitude  Year  Month  Day  \
# 0                1  2018-02-14     0 -73.575661  45.48265  2018      2   14
# 1                1  2018-02-14     1 -73.575661  45.48265  2018      2   14
# 2                1  2018-02-14     2 -73.575661  45.48265  2018      2   14
# 3                1  2018-02-14     3 -73.575661  45.48265  2018      2   14
# 4                1  2018-02-14     4 -73.575661  45.48265  2018      2   14
#
#    weekday  NB  SB  EB  WB  wind_speed  temperature  visibility  \
# 0        2   0   0   0   0         2.0        -10.4     24100.0
# 1        2   0   0   0   0         7.0        -11.5     24100.0
# 2        2   0   0   0   0         3.0        -12.1     24100.0
# 3        2   0   0   0   0         9.0         -7.9     24100.0
# 4        2   0   0   0   0        13.0         -6.5     24100.0
#
#    collision_nearby
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
collisions.head()
# Out:
#          date       lat       lon  year  month  day  hour  weekday  \
# 0  2012-06-02  45.48772 -73.71603  2012      6    2    15        5
# 1  2012-06-28  45.51432 -73.68279  2012      6   28     8        3
# 2  2012-07-11  45.49221 -73.57647  2012      7   11     9        2
# 3  2012-01-02  45.48687 -73.87855  2012      1    2    14        0
# 4  2012-01-03  45.49170 -73.85536  2012      1    3    12        1
#
#    num_vehicles  num_victims
# 0             1            0
# 1             2            0
# 2             2            0
# 3             2            0
# 4             2            0

# %%
# binarize collision_nearby
new['is_collision'] = np.where(new['collision_nearby'] > 0, 1, 0)

# drop some non-useful columns
new.drop(columns=['Id_Intersection', 'Date', 'collision_nearby'], inplace=True)

# check results
new.head()
# Out:
#    hour  Longitude  Latitude  Year  Month  Day  weekday  NB  SB  EB  WB  \
# 0     0 -73.575661  45.48265  2018      2   14        2   0   0   0   0
# 1     1 -73.575661  45.48265  2018      2   14        2   0   0   0   0
# 2     2 -73.575661  45.48265  2018      2   14        2   0   0   0   0
# 3     3 -73.575661  45.48265  2018      2   14        2   0   0   0   0
# 4     4 -73.575661  45.48265  2018      2   14        2   0   0   0   0
#
#    wind_speed  temperature  visibility  is_collision
# 0         2.0        -10.4     24100.0             0
# 1         7.0        -11.5     24100.0             0
# 2         3.0        -12.1     24100.0             0
# 3         9.0         -7.9     24100.0             0
# 4        13.0         -6.5     24100.0             0

# %%
# import the different sklearn packages we will need
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
# ensure that the dataset is sorted by date-time
new.sort_values(['Year', 'Month', 'Day', 'hour'], inplace=True)
new.head()
# Out:
#        hour  Longitude   Latitude  Year  Month  Day  weekday  NB  SB  EB  WB  \
# 49522     0 -73.615006  45.627322  2012      1   19        3   0   0   0   0
# 49523     1 -73.615006  45.627322  2012      1   19        3   0   0   0   0
# 49524     2 -73.615006  45.627322  2012      1   19        3   0   0   0   0
# 49525     3 -73.615006  45.627322  2012      1   19        3   0   0   0   0
# 49526     4 -73.615006  45.627322  2012      1   19        3   0   0   0   0
#
#        wind_speed  temperature  visibility  is_collision
# 49522         7.0        -16.6     25000.0             0
# 49523         4.0        -15.2     25000.0             0
# 49524         6.0        -14.3     25000.0             0
# 49525         6.0        -18.0     25000.0             0
# 49526         7.0        -15.4     25000.0             0

# %%
# split into features and target
X = new.iloc[:, :-1]
y = new['is_collision']

# train test split with the shuffle set to False
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99, shuffle=False)

# %%
dt = DecisionTreeClassifier(max_depth=5)
dt.fit(X_train, y_train);

dt.score(X_train, y_train)
# Out:
# 0.7079991703539823

# %%
dt.score(X_test, y_test)
# Out:
# 0.7242118362831859

# %% [markdown]
# So at this point, we have the trained model.  What I need is
# 1. The lat/lon values of the intersections which we use
# 2. The lat/lon values of the collisions which occurred nearby
# 3. The probabilities for each intersection which we use

# %% [markdown]
# - `test_collisions` gives me the locations of the collisions
# -

# %%
test_rows = new.loc[(new['Year'] == 2018) & (new['Month'] == 2) & (new['Day'] == 14) \
                      & (new['hour'] == 8), :]
test_rows
# Out:
#        hour  Longitude   Latitude  Year  Month  Day  weekday   NB   SB   EB  \
# 8         8 -73.575661  45.482650  2018      2   14        2  466  146  294
# 5570      8 -73.587639  45.473984  2018      2   14        2    0    2  354
# 5866      8 -73.574439  45.483398  2018      2   14        2   68   79  387
# 11432     8 -73.562987  45.495417  2018      2   14        2  969  338  754
# 22711     8 -73.571767  45.485016  2018      2   14        2   56  151  368
# 51327     8 -73.563755  45.494298  2018      2   14        2    1  103  723
# 56709     8 -73.573591  45.481004  2018      2   14        2  514  241  142
#
#         WB  wind_speed  temperature  visibility  is_collision
# 8      347         4.0         -8.0     24100.0             1
# 5570   324         4.0         -8.0     24100.0             0
# 5866   308         4.0         -8.0     24100.0             1
# 11432  164         4.0         -8.0     24100.0             1
# 22711  297         4.0         -8.0     24100.0             1
# 51327  206         4.0         -8.0     24100.0             1
# 56709    0         4.0         -8.0     24100.0             0

# %%
X_test_rows = test_rows.iloc[:, :-1]
y_test_rows = test_rows['is_collision']

probs = dt.predict_proba(X_test_rows)
ones = [round(x[1], 2) for x in probs]

test_rows['prob'] = ones
test_rows['pred'] = np.where(test_rows['prob'] > 0.5, 1, 0)
test_rows
# Out:
#        hour  Longitude   Latitude  Year  Month  Day  weekday   NB   SB   EB  \
# 8         8 -73.575661  45.482650  2018      2   14        2  466  146  294
# 5570      8 -73.587639  45.473984  2018      2   14        2    0    2  354
# 5866      8 -73.574439  45.483398  2018      2   14        2   68   79  387
# 11432     8 -73.562987  45.495417  2018      2   14        2  969  338  754
# 22711     8 -73.571767  45.485016  2018      2   14        2   56  151  368
# 51327     8 -73.563755  45.494298  2018      2   14        2    1  103  723
# 56709     8 -73.573591  45.481004  2018      2   14        2  514  241  142
#
#         WB  wind_speed  temperature  visibility  is_collision  prob  pred
# 8      347         4.0         -8.0     24100.0             1  0.68     1
# 5570   324         4.0         -8.0     24100.0             0  0.32     0
# 5866   308         4.0         -8.0     24100.0             1  0.68     1
# 11432  164         4.0         -8.0     24100.0             1  0.68     1
# 22711  297         4.0         -8.0     24100.0             1  0.68     1
# 51327  206         4.0         -8.0     24100.0             1  0.68     1
# 56709    0         4.0         -8.0     24100.0             0  0.68     1

# %%
test_rows.to_csv('../Data/Montreal/Final/predictions_intersections.csv', index=False)

# %%
test_collisions = collisions.loc[(collisions['year'] == 2018) & \
                                 (collisions['month'] == 2) & \
                                 (collisions['day'] == 14) & \
                                 (collisions['hour'] > 5) & (collisions['hour'] < 11), :]

test_collisions.head()
# Out:
#               date       lat       lon  year  month  day  hour  weekday  \
# 136061  2018-02-14  45.48618 -73.70376  2018      2   14     6        2
# 138887  2018-02-14  45.49123 -73.59608  2018      2   14     7        2
# 139284  2018-02-14  45.42822 -73.61017  2018      2   14    10        2
# 141407  2018-02-14  45.49781 -73.55969  2018      2   14     9        2
# 144311  2018-02-14  45.52685 -73.64946  2018      2   14     8        2
#
#         num_vehicles  num_victims
# 136061             8            1
# 138887             2            0
# 139284             2            1
# 141407             2            0
# 144311             2            1

# %%
test_collisions.shape
# Out:
# (8, 10)

# %%
test_collisions.to_csv('../Data/Montreal/Final/predictions_collisions.csv', index=False)

# %%
pd.set_option('max_columns', None)

# %%
test_collisions['Longitude'] = test_collisions['lon']
test_collisions['Latitude'] = test_collisions['lat']
test_collisions.head()
# Out:
#               date       lat       lon  year  month  day  hour  weekday  \
# 136061  2018-02-14  45.48618 -73.70376  2018      2   14     6        2
# 138887  2018-02-14  45.49123 -73.59608  2018      2   14     7        2
# 139284  2018-02-14  45.42822 -73.61017  2018      2   14    10        2
# 141407  2018-02-14  45.49781 -73.55969  2018      2   14     9        2
# 144311  2018-02-14  45.52685 -73.64946  2018      2   14     8        2
#
#         num_vehicles  num_victims  Longitude  Latitude
# 136061             8            1  -73.70376  45.48618
# 138887             2            0  -73.59608  45.49123
# 139284             2            1  -73.61017  45.42822
# 141407             2            0  -73.55969  45.49781
# 144311             2            1  -73.64946  45.52685

# %%
test_collisions['is_intersection'] = 0
test_rows['is_intersection'] = 1

# %%
test_collisions['colour_scheme'] = 1
test_rows['colour_scheme'] = np.where(test_rows['pred'] == 1, 2, 3)

# %%
test = pd.concat([test_rows, test_collisions])

# %%
test
# Out:
#         hour  Longitude   Latitude    Year  Month   Day  weekday     NB  \
# 8          8 -73.575661  45.482650  2018.0    2.0  14.0        2  466.0
# 5570       8 -73.587639  45.473984  2018.0    2.0  14.0        2    0.0
# 5866       8 -73.574439  45.483398  2018.0    2.0  14.0        2   68.0
# 11432      8 -73.562987  45.495417  2018.0    2.0  14.0        2  969.0
# 22711      8 -73.571767  45.485016  2018.0    2.0  14.0        2   56.0
# 51327      8 -73.563755  45.494298  2018.0    2.0  14.0        2    1.0
# 56709      8 -73.573591  45.481004  2018.0    2.0  14.0        2  514.0
# 136061     6 -73.703760  45.486180     NaN    NaN   NaN        2    NaN
# 138887     7 -73.596080  45.491230     NaN    NaN   NaN        2    NaN
# 139284    10 -73.610170  45.428220     NaN    NaN   NaN        2    NaN
# 141407     9 -73.559690  45.497810     NaN    NaN   NaN        2    NaN
# 144311     8 -73.649460  45.526850     NaN    NaN   NaN        2    NaN
# 144821     9 -73.642140  45.489680     NaN    NaN   NaN        2    NaN
# 145827     6 -73.628090  45.551440     NaN    NaN   NaN        2    NaN
# 146672    10 -73.599470  45.559260     NaN    NaN   NaN        2    NaN
#
#            SB     EB     WB  wind_speed  temperature  visibility  \
# 8       146.0  294.0  347.0         4.0         -8.0     24100.0
# 5570      2.0  354.0  324.0         4.0         -8.0     24100.0
# 5866     79.0  387.0  308.0         4.0         -8.0     24100.0
# 11432   338.0  754.0  164.0         4.0         -8.0     24100.0
# 22711   151.0  368.0  297.0         4.0         -8.0     24100.0
# 51327   103.0  723.0  206.0         4.0         -8.0     24100.0
# 56709   241.0  142.0    0.0         4.0         -8.0     24100.0
# 136061    NaN    NaN    NaN         NaN          NaN         NaN
# 138887    NaN    NaN    NaN         NaN          NaN         NaN
# 139284    NaN    NaN    NaN         NaN          NaN         NaN
# 141407    NaN    NaN    NaN         NaN          NaN         NaN
# 144311    NaN    NaN    NaN         NaN          NaN         NaN
# 144821    NaN    NaN    NaN         NaN          NaN         NaN
# 145827    NaN    NaN    NaN         NaN          NaN         NaN
# 146672    NaN    NaN    NaN         NaN          NaN         NaN
#
#         is_collision  prob  pred  is_intersection  colour_scheme        date  \
# 8                1.0  0.68   1.0                1              2         NaN
# 5570             0.0  0.32   0.0                1              3         NaN
# 5866             1.0  0.68   1.0                1              2         NaN
# 11432            1.0  0.68   1.0                1              2         NaN
# 22711            1.0  0.68   1.0                1              2         NaN
# 51327            1.0  0.68   1.0                1              2         NaN
# 56709            0.0  0.68   1.0                1              2         NaN
# 136061           NaN   NaN   NaN                0              1  2018-02-14
# 138887           NaN   NaN   NaN                0              1  2018-02-14
# 139284           NaN   NaN   NaN                0              1  2018-02-14
# 141407           NaN   NaN   NaN                0              1  2018-02-14
# 144311           NaN   NaN   NaN                0              1  2018-02-14
# 144821           NaN   NaN   NaN                0              1  2018-02-14
# 145827           NaN   NaN   NaN                0              1  2018-02-14
# 146672           NaN   NaN   NaN                0              1  2018-02-14
#
#              lat       lon    year  month   day  num_vehicles  num_victims
# 8            NaN       NaN     NaN    NaN   NaN           NaN          NaN
# 5570         NaN       NaN     NaN    NaN   NaN           NaN          NaN
# 5866         NaN       NaN     NaN    NaN   NaN           NaN          NaN
# 11432        NaN       NaN     NaN    NaN   NaN           NaN          NaN
# 22711        NaN       NaN     NaN    NaN   NaN           NaN          NaN
# 51327        NaN       NaN     NaN    NaN   NaN           NaN          NaN
# 56709        NaN       NaN     NaN    NaN   NaN           NaN          NaN
# 136061  45.48618 -73.70376  2018.0    2.0  14.0           8.0          1.0
# 138887  45.49123 -73.59608  2018.0    2.0  14.0           2.0          0.0
# 139284  45.42822 -73.61017  2018.0    2.0  14.0           2.0          1.0
# 141407  45.49781 -73.55969  2018.0    2.0  14.0           2.0          0.0
# 144311  45.52685 -73.64946  2018.0    2.0  14.0           2.0          1.0
# 144821  45.48968 -73.64214  2018.0    2.0  14.0           2.0          0.0
# 145827  45.55144 -73.62809  2018.0    2.0  14.0           3.0          0.0
# 146672  45.55926 -73.59947  2018.0    2.0  14.0           2.0          0.0

# %%
test.to_csv('../Data/Montreal/Final/predictions.csv', index=False)

# %%
test['L']
